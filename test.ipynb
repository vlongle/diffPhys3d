# %%
import pickle

# %%
def load_pickle(path):
    with open(path, 'rb') as f:
        return pickle.load(f)

# %%
final_dataset = load_pickle('final_dataset.pkl')

# %%
final_dataset["tree"]
# Out:
# [('bd7503a48e4546babf004da9dbb11318', 0.8438878059387207),
#  ('e949ca79ce42407f81ae43b613a5b94e', 0.7551958560943604),
#  ('3d9a9f41acc54e62bfcf207066cda282', 0.7456215620040894),
#  ('39c14b1d1d63467588ab6bd44a5525d0', 0.7345844507217407),
#  ('e9b8424bfcf34f679f5d6c212a221447', 0.7321165800094604),
#  ('a4277a2f92d343f8b1b3ca0c7a533baf', 0.7321165800094604),
#  ('9ea6866e40294eaeaa82b2a63794be93', 0.7321165800094604),
#  ('de9c3aca3612458ea147140845131c42', 0.7321165800094604),
#  ('38531afd86434987b1a0bf5968fe001f', 0.7321165800094604),
#  ('0773992894ef4747b94f03e6eb69d620', 0.7321165800094604),
#  ('515ff7eff08144e3be70a89eedbcbcc7', 0.7321165800094604),
#  ('9662ae04d8354b7cb0f22ecc6c983a60', 0.7321165800094604),
#  ('9bbdddddc4b644a1bcaed9423eeec7b9', 0.7321165800094604),
#  ('9403d661104349f5b1fbf948c0e2afb0', 0.7321165800094604),
#  ('eaec8082c0af4ea6bf7efec8d7253b56', 0.7321165204048157),
#  ('1cec99d96a5043e1a6997e106d00c09a', 0.6879897117614746),
# ...
